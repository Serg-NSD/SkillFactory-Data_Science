# %% [markdown]
# ## Игра угадай число

# %%
from game_v2 import score_game
from game_v2 import random_predict

# %% [markdown]
# ### Угадываем рандомно

# %%
score_game(random_predict)
# Out:
# число:  73
# число:  73
# число:  96
# число:  96
# число:  44
# число:  44
# число:  61
# число:  61
# число:  20
# число:  20
# число:  68
# число:  68
# число:  63
# число:  63
# число:  85
# число:  85
# число:  33
# число:  33
# число:  24
# число:  24
# число:  8
# число:  8
# число:  26
# число:  26
# число:  7
# число:  7
# число:  7
# число:  7
# число:  93
# число:  93
# число:  86
# число:  86
# число:  94
# число:  94
# число:  93
# число:  93
# число:  33
# число:  33
# число:  54
# число:  54
# число:  48
# число:  48
# число:  47
# число:  47
# число:  10
# число:  10
# число:  47
# число:  47
# число:  23
# число:  23
# число:  100
# число:  100
# число:  37
# число:  37
# число:  42
# число:  42
# число:  3
# число:  3
# число:  51
# число:  51
# число:  49
# число:  49
# число:  73
# число:  73
# число:  53
# число:  53
# число:  76
# число:  76
# число:  52
# число:  52
# число:  83
# число:  83
# число:  31
# число:  31
# число:  88
# число:  88
# число:  46
# ...
